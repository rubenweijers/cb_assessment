# %%
import pandas as pd

# %%
df = pd.read_csv('../cb_assessment/files/Total visits and contact ratio per Q&A  - Total visits and contact ratio per Q&A and self service usage.csv')
json1 = pd.read_json('../cb_assessment/files/Product_Support_artikels.json')
json2 = pd.read_json('../cb_assessment/files/questions_and_answers.json')

# %%
df.head(2)
# Out:
#                                                Label                 Category  \
# 0  kunnen-jullie-me-helpen-bij-de-installatie-en-...  Advies en ondersteuning
# 1            hoeveel-garantie-heb-ik-op-mijn-product    Garantie en reparatie
#
#                               Item Total clicks Contact ratio  Total contacts
# 0  Hulp bij installatie en gebruik         1,3K        78,90%             595
# 1              Garantievoorwaarden         1,2K        64,00%             500

# %%
json1.head(2)
# Out:
#   flattenedProductIds products              lastModified articleType  \
# 0                           {}  2023-08-04T09:19:51.984Z    advisory
# 1                           {}  2023-08-04T09:19:51.984Z    advisory
#
#                                      id  \
# 0  60f5ecf3-82fa-476f-81ca-276e89a94445
# 1  60f5ecf3-82fa-476f-81ca-276e89a94445
#
#                                                title   lang  \
# 0       Kloppen, kneden en mixen met een keukenrobot  nl-nl
# 1  How do you whisk, knead, and mix with a stand ...  en-be
#
#                       article_lang_country_id language country  ...  \
# 0  60f5ecf3-82fa-476f-81ca-276e89a94445-nl-nl       nl      nl  ...
# 1  60f5ecf3-82fa-476f-81ca-276e89a94445-en-be       en      be  ...
#
#              lastReviewedAt     categoryId  isSupportArticle sourceLanguage  \
# 0  2023-08-04T09:19:51.984Z  helpWithUsage              True             nl
# 1  2023-08-04T09:19:51.984Z  helpWithUsage              True             nl
#
# ...

# %%
json2.head(2)
# Out:
#                                        question  \
# 0  Kan ik mijn factuur als e-factuur ontvangen?
# 1    Heeft Coolblue een veilige betaalomgeving?
#
#                                               answer
# 0  Ja, we kunnen jouw factuur ook als een XML-bes...
# 1  Ja. Zodra je begint met afrekenen kom je terec...
